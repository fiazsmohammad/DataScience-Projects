# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv("C:\\Users\\fiazm\\OneDrive\\Desktop\\weather_classification_data.csv")
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 13195         10.0        74        14.5               71.0       overcast
# 13196         -1.0        76         3.5               23.0         cloudy
# 13197         30.0        77         5.5               28.0       overcast
# 13198          3.0        76        10.0               94.0       overcast
# 13199         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
df.describe()
# Out:
#         Temperature      Humidity    Wind Speed  Precipitation (%)  \
# count  13200.000000  13200.000000  13200.000000       13200.000000
# mean      19.127576     68.710833      9.832197          53.644394
# std       17.386327     20.194248      6.908704          31.946541
# min      -25.000000     20.000000      0.000000           0.000000
# 25%        4.000000     57.000000      5.000000          19.000000
# 50%       21.000000     70.000000      9.000000          58.000000
# 75%       31.000000     84.000000     13.500000          82.000000
# max      109.000000    109.000000     48.500000         109.000000
#
#        Atmospheric Pressure      UV Index  Visibility (km)
# count          13200.000000  13200.000000     13200.000000
# mean            1005.827896      4.005758         5.462917
# std               37.199589      3.856600         3.371499
# min              800.120000      0.000000         0.000000
# 25%              994.800000      1.000000         3.000000
# ...

# %%
df.dropna()
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 13195         10.0        74        14.5               71.0       overcast
# 13196         -1.0        76         3.5               23.0         cloudy
# 13197         30.0        77         5.5               28.0       overcast
# 13198          3.0        76        10.0               94.0       overcast
# 13199         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
m=df['Weather Type'].value_counts()
plt.pie(m,labels=m.index,autopct='%1.1f%%')
plt.title("Distribution of Weather")
plt.show()

# %%
plt.scatter(df['Temperature'],df['Humidity'],color='Red')
plt.title('Relationship Between Temperature and Humidity')
plt.xlabel('Temperature °C')
plt.ylabel('Humidity %')
plt.grid(True)
plt.show()

# %%
plt.scatter(df['Wind Speed'],df['Precipitation (%)'],color='Red')
plt.title('Relationship Between Wind Speed and Precipitation')
plt.xlabel('Wind Speed')
plt.ylabel('Precipitation (%)')
plt.grid(True)
plt.show()

# %%
plt.scatter(df['Precipitation (%)'],df['Visibility (km)'],color='Red')
plt.title('Relationship Between Visibility and Precipitation')
plt.xlabel('Precipitation (%)')
plt.ylabel('Visibility')
plt.grid(True)
plt.show()

# %%
b=df['Season'].value_counts()
plt.pie(b,labels=b.index,autopct='%1.1f%%')
plt.title("Distribution of Season")
plt.show()

# %%
plt.subplot(1, 3, 1)
plt.hist(df['Temperature'], color='skyblue', edgecolor='black')
plt.title('Temperature Distribution')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')
plt.subplot(1, 3, 2)
plt.hist(df['Humidity'], color='lightgreen', edgecolor='black')
plt.title('Humidity Distribution')
plt.xlabel('Humidity (%)')
plt.ylabel('Frequency')
plt.subplot(1, 3, 3)
plt.hist(df['Wind Speed'], color='salmon', edgecolor='black')
plt.title('Wind Speed Distribution')
plt.xlabel('Wind Speed (km/h)')
plt.ylabel('Frequency')
plt.show()

# %%
from scipy import sparse
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

one_hot_encoder = OneHotEncoder()
X_encoded = one_hot_encoder.fit_transform(x[categorical_columns])

scaler = StandardScaler()
X_scaled = scaler.fit_transform(x[numerical_columns])
if sparse.issparse(X_scaled):
    X_scaled = X_scaled.toarray()
X_preprocessed = sparse.hstack((X_scaled, X_encoded))
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(y_pred)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# ['Sunny' 'Sunny' 'Sunny' ... 'Snowy' 'Snowy' 'Cloudy']
# Accuracy: 0.8912878787878787
#               precision    recall  f1-score   support
#
#       Cloudy       0.85      0.87      0.86       651
#        Rainy       0.86      0.88      0.87       647
#        Snowy       0.93      0.94      0.93       701
#        Sunny       0.93      0.88      0.90       641
#
#     accuracy                           0.89      2640
#    macro avg       0.89      0.89      0.89      2640
# weighted avg       0.89      0.89      0.89      2640

# %%
from sklearn.svm import SVC
machine=SVC()
machine.fit(X_train, y_train)
pred = machine.predict(X_test)
print(pred)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# ['Sunny' 'Sunny' 'Sunny' ... 'Snowy' 'Snowy' 'Cloudy']
# Accuracy: 0.8912878787878787
#               precision    recall  f1-score   support
#
#       Cloudy       0.85      0.87      0.86       651
#        Rainy       0.86      0.88      0.87       647
#        Snowy       0.93      0.94      0.93       701
#        Sunny       0.93      0.88      0.90       641
#
#     accuracy                           0.89      2640
#    macro avg       0.89      0.89      0.89      2640
# weighted avg       0.89      0.89      0.89      2640

# %%
from sklearn.ensemble import RandomForestClassifier
forest=RandomForestClassifier()
forest.fit(X_train, y_train)
forest_predict=forest.predict(X_test)
print(forest_predict)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# ['Sunny' 'Sunny' 'Sunny' ... 'Snowy' 'Snowy' 'Cloudy']
# Accuracy: 0.8912878787878787
#               precision    recall  f1-score   support
#
#       Cloudy       0.85      0.87      0.86       651
#        Rainy       0.86      0.88      0.87       647
#        Snowy       0.93      0.94      0.93       701
#        Sunny       0.93      0.88      0.90       641
#
#     accuracy                           0.89      2640
#    macro avg       0.89      0.89      0.89      2640
# weighted avg       0.89      0.89      0.89      2640

# %%
from sklearn.naive_bayes import GaussianNB
naive=GaussianNB()
naive = GaussianNB()
naive.fit(X_train, y_train)
naive_predict = naive.predict(X_test)
print(naive_predict)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# ['Sunny' 'Sunny' 'Cloudy' ... 'Snowy' 'Snowy' 'Cloudy']
# Accuracy: 0.8912878787878787
#               precision    recall  f1-score   support
#
#       Cloudy       0.85      0.87      0.86       651
#        Rainy       0.86      0.88      0.87       647
#        Snowy       0.93      0.94      0.93       701
#        Sunny       0.93      0.88      0.90       641
#
#     accuracy                           0.89      2640
#    macro avg       0.89      0.89      0.89      2640
# weighted avg       0.89      0.89      0.89      2640

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(X_train, y_train)
log_predict=log.predict(X_test)
print(log_predict)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# ['Sunny' 'Sunny' 'Sunny' ... 'Snowy' 'Snowy' 'Cloudy']
# Accuracy: 0.8912878787878787
#               precision    recall  f1-score   support
#
#       Cloudy       0.85      0.87      0.86       651
#        Rainy       0.86      0.88      0.87       647
#        Snowy       0.93      0.94      0.93       701
#        Sunny       0.93      0.88      0.90       641
#
#     accuracy                           0.89      2640
#    macro avg       0.89      0.89      0.89      2640
# weighted avg       0.89      0.89      0.89      2640
